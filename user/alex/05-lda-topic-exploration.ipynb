# %%
# %load_ext autoreload
# %autoreload 2

# %%
from longeval.spark import get_spark
import os
import pandas as pd

os.environ['SPARK_LOCAL_DIR'] = '/home/ap/github/longeval-2025/.venv/lib/python3.10/site-packages/pyspark'
os.environ['JAVA_HOME'] = '/usr/lib/jvm/java-11-openjdk-amd64' 
os.environ['SPARK_HOME'] = '/opt/spark-3.5.4-bin-hadoop3'

data_root = "../../data/longeval"

spark = get_spark()
spark.sparkContext.setLogLevel("ERROR")
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ap-HP-Z2-Tower-G4-Workstation.fritz.box:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.4</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[12]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>longeval</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data_root = "../../data/longeval"
! tree {data_root} -L 3
# Out:
# ../../data/longeval
# ├── 2023_01
# │   ├── English
# │   │   ├── Documents
# │   │   ├── Qrels
# │   │   └── Queries
# │   └── French
# │       ├── Documents
# │       ├── Qrels
# │       └── Queries
# └── count_docs.sh
#
# 9 directories, 1 file

# %%
import os
os.environ['PYSPARK_DRIVER_MEMORY'] = '16G'
print(os.environ.get('PYSPARK_DRIVER_MEMORY'))
# Out:
# 16G

# %%
from longeval.collection import RawCollection

# according to a simple grep, there are 1759690 documents in the collection
train_eng = RawCollection(
    spark, f"{data_root}/2023_01/English"
)
docs = train_eng.documents.cache()
print(docs.count())
docs.show(5, vertical=True, truncate=80)
docs.printSchema()
# Out:
# [Stage 902:>                                                        (0 + 1) / 1]
# 1260
# -RECORD 0------------------------------------------------------------------------------------
#  contents | Forget the Nukes:\nTunnels\nAre North\nKorea's Secret Weapon\n|\nThe\nNationa...
#  docid    | doc012310000001
# -RECORD 1------------------------------------------------------------------------------------
#  contents | Project Perfect Mod ::\nView topic\n- Who will take over the island?\nDo you ...
#  docid    | doc012310000002
# -RECORD 2------------------------------------------------------------------------------------
#  contents | "Lawyer James B. Donovan, widely known for negotiating the release of...\nNie...
#  docid    | doc012310000003
# -RECORD 3------------------------------------------------------------------------------------
#  contents | What Rex Tillerson'\ns Nomination Means for Russia\nPolicy\n|\nThe\nNational ...
#  docid    | doc012310000004
# -RECORD 4------------------------------------------------------------------------------------
#  contents | Issan\n- Collection\n|\nPokechange\nThe Collection\nCollection content.\nFilt...
#  docid    | doc012310000005
# only showing top 5 rows
#
# root
#  |-- contents: string (nullable = true)
#  |-- docid: string (nullable = true)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, col, explode, collect_list, expr
from pyspark.sql.types import ArrayType, StringType, IntegerType
from pyspark.ml.feature import Tokenizer, StopWordsRemover, CountVectorizer
from pyspark.ml.clustering import LDA
import numpy as np
from pyspark.sql.functions import col, array_max, array_position


# Assuming Spark session is already created
spark = SparkSession.builder.appName("LDA Example").getOrCreate()
spark.sparkContext.setLogLevel("ERROR")

# Step 1: Tokenization
tokenizer = Tokenizer(inputCol="contents", outputCol="words")
tokenized = tokenizer.transform(docs)

# Step 2: Remove Stopwords
remover = StopWordsRemover(inputCol="words", outputCol="filtered_words")
filtered = remover.transform(tokenized)

# Step 3: Convert Words to Features using CountVectorizer
vectorizer = CountVectorizer(inputCol="filtered_words", outputCol="features")
vector_model = vectorizer.fit(filtered)
vectorized_docs = vector_model.transform(filtered)
# vectorized_docs.printSchema()  

# Step 4: Train LDA Model
k = 20  # Number of topics to extract
lda = LDA(k=k, maxIter=10, featuresCol="features", optimizer="em")
lda_model = lda.fit(vectorized_docs)

# Step 5: Extract Topics
topics = lda_model.describeTopics(maxTermsPerTopic=100)
vocab = vector_model.vocabulary  # Get vocabulary

# Ensure the vocabulary is not empty
if not vocab:
    raise ValueError("Vocabulary is empty. Please check the CountVectorizer step.")

# topics.show(truncate=False)  # This will display all topics without truncating

# Step 6: Map topics to words
topic_words = {}
for row in topics.collect():
    topic_index = row.topic
    term_indices = row.termIndices
    terms = [vocab[index] for index in term_indices]  # Map indices to words
    topic_words[topic_index] = terms

# Print the mapped topics to words
for topic, words in topic_words.items():
    print(f"Topic {topic}: {', '.join(words)}")


topic_distributions = lda_model.transform(vectorized_docs)

# topic_distributions.printSchema()
# # Show the first few rows of topic_distributions
# topic_distributions.show(truncate=False)
# topic_distributions.head(3)


# Step 8: Select the relevant columns
doc_topic_df = topic_distributions.select("docid", "topicDistribution").toPandas()
# Extract the topic probabilities as a NumPy array
doc_topic_array = np.vstack(doc_topic_df["topicDistribution"].apply(lambda v: v.toArray()))
# Step 7: Identify the topic with the highest probability
doc_topic_df['highest_topic'] = np.argmax(doc_topic_array, axis=1)  # Get index of the highest topic
# Convert the topic probabilities array back to a DataFrame
topic_probabilities_df = pd.DataFrame(doc_topic_array, columns=[f'topic_{i}' for i in range(doc_topic_array.shape[1])])
# Concatenate the docid, highest_topic, and topic probabilities
result_df = pd.concat([doc_topic_df[['docid']], 
                       pd.DataFrame({'highest_topic': doc_topic_df['highest_topic']}), 
                       topic_probabilities_df], axis=1)

result_df.head(10)
# Out:
# Topic 0:  , -, montmagny, 1, use, /, 5, ,, one, also, new, free, information, may, 2, &, water, montmagny., us, 3, :, first, individual, please, services, open, repair, 4, •, general, support, make, good, hotel, time, see, search, foam, like, $, made, france, focus, +, service, must, 0, data, 10, remediation, collection, without, take, year, |, rated, create, contact, available, health, (, view, find, 6, change, 2023, get, much, years, *, ., springs, brilliant, –, average, work, need, two, , 2022, city, know, day, click, grease, right, number, site, km, files, used, €, even, last, many, air, name, well, united, email
# Topic 1: -, best, new, film, ,, /, 1, award, de, one, may, also, 2, km, france, first, time, winning, 3, use, card, life, us, takes, share, like, |, ..., see, euro, 5, (, information, festival, contact, black, international, take, french, good, 2012, –, photo, :, 2011, war, two, 2017, years, social, 10, avenue, water, book, volvo, member, &, 2018, search, free, city, hotel, italy, accepted, school, recommended, patients, know, 2013, family, people, little, price, make, 100, without, well, old, read, comedy, made, academy, ©, since, must, site, modify, paris, centre, work, find, service, tractor, 51, public, occasion, 4, number, part, many
# Topic 2: ., -, ,, hope, may, use, one, fr, 1, &, also, information, new, us, save, 3, stamps, first, get, 2, |, time, number, love, per, _, :, de, page, like, without, work, day, services, email, 5, public, free, service, personal, make, see, people, good, search, days, shall, 4, site, 10, policy, know, please, order, engineering, well, access, many, –, book, la, find, (, take, last, contact, ", president, two, health, location:, stock, help, year, read, data, even, support, date, hotel, great, 8, 6, top, used, quality, offers, ..., test, little, part, 2022, suggestive, 38, years, website, /, 0, since, must
# Topic 3: ,,  , -, ., ), /, (l), (g3), one, also, (g1), may, academic, instagram, |, top, new, use, (g2), &, time, like, 1, all:1-1(1), us, first, information, make, de, many, get, order, number, season:1-1(1), last, note, work, (, find, general, part, audience, ps, take, outlet, free, people, honesty, without, =, see, two, water, much, even, full, used, core, data, right, , please, 2, good, engagement, know, cancer, account, wedding, need, well, day, analysis, email, made, forum, per, high, contact, hard, title, give, quality, since, season:1-1(0), view, years, must, policy, report, [, want, lc-pcc, three, 3, following, little, french, way, benadryl
# Topic 4: (1), ,, (0), de, :, et, -, good, one, hotel, new, 2, discover, also, (2), first, 1, _, free, paris, may, time, 3, use, bistrot, get, us, two, online, restaurant, make, like, days, 4, paper, information, products, take, price, 0, without, ..., order, ago, –, even, see, la, right, years, km, |, (, 10, &, since, find, please, 5, many, must, (3), need, essay, know, site, well, ring, /, best, people, accessories, 406, supplies, french, south, exit, made, number, city, work, service, back, united, ✦, start, little, à, read, water, 6, contact, hotels, less, hdi, islands, watch, love, world, en
# Topic 5: -, ,, ., a., 3, de, price, model, 1, committee, free, &, new, use, also, one, may, 2, information, athletics, first, premium, us, states, united, flowers, m., s., 0, ago, |, usa, power, day, atf, order, ac, time, add, year, food, :, tesla, club, hotel, electro, service, see, 2022, contact, online, bordeaux, la, like, good, km, without, days, /, make, please, email, –, take, 2019, (, last, van, available, journal, services, 10, find, website, red, access, 2018, ltm, health, search, two, 5, well, series, twil, years, adel, january, get, right, 4, du, people, research, work, air, quality, mi, car, personal
# Topic 6: -, lycée, de, &, puzzles, paris, ,, school, new, also, test, one, 1, 3, 2, us, university, first, information, la, use, 5, may, jean, clamping, /, time, free, –, college, mb, (, 4, good, 0, see, |, sale, like, without, control, service, last, english, faculty, contact, make, work, business, bricks, number, (original, order, france, find, :, machine, €, puzzle, 10, hollow, available, price, two, search, used, brick, french, high, many, european, take, management, 6, site, place, please, data, national, people, years, human, per, day, international, elements, part, well, *, view, des, need, cookies, must, know, set, world, days, 2018, made
# Topic 7: -, x, 5, air, de, ,, /, 1, 2, la, also, new, mm, vat, gironde, display, one, adelphane, delivery, 4, information, best, esidrex, first, may, 3, use, conseil, chf, h, l, weeks, work, +, free, minimum, (33074), please, ], excluding, time, us, airlines, well, (, like, good, buy, service, services, 100, départemental, doors, contact, number, show, order, see, get, make, |, without, –, [ref., online, public, two, years, house, day, 6, take, available, french, find, &, days, stars, :, back, water, department, *, place, even, 10, variants, quality, following, need, search, great, products, right, 1950, €, last, data, know, many
# Topic 8: ., vanves, electrical, use, online, -, installation, new, also, one, may, free, ,, 92170., comments, information, victor, electricity, de, us, chez, work, time, without, price, water, must, get, first, many, 92170, company, order, like, guide, electrician, 1, professional, card, health, pdf, –, &, treatment, mediterranean, people, service, made, member, find, loyalty, take, search, download, make, book, 2, using, contact, two, la, european, equipment, pharmacy, 5, see, photo, well, house, works, good, flora, thousand, even, best, receive, energy, news, dream, 0:0, industrial, know, please, available, read, conditions, years, number, view, site, used, data, help, start, /, en, great, account, much, france
# Topic 9: -, world, 3, nights, cup, 2, 15, ,, slalom, 1, /, km, giant, 5, 10, 4, wc, 3d, use, de, c, 12, information, new, one, f, article), (link, may, 9, time, (brief, also, _, fis, gewinnt, 8, 7, |, national, 6, stage, us, like, air, 13, –, slots, first, free, number, service, final, reel, 30, 20, european, place, please, points, swc, alien, (, 11, without, 2022, last, &, la, 18, [, ), site, work, people, two, services, 02, see, val, 22, search, take, make, get, !, 2009, top, sp, day, available, posted:, 14, days, presidential, public, good, post, website, 50
# Topic 10: -, ,, /, _, 0, new, one, 1, 2, also, &, first, 3, get, 5, may, use, information, like, |, us, [, de, north, time, see, well, number, |   |, ", good, email, island, 4, free, –, find, 10, years, data, make, day, 0%, people, :, two, forum, take, last, per, french, without, many, islands, 6, need, site, products, ), love, service, low, rain, doors, order, made, name, (, much, republic, group, news, services, know, *, playback, work, mph, united, today], ago, please, even, 8, , part, right, hybrid, 7, back, spf:, m, read, search, go, top, available, a4, food, die
# Topic 11: _, |, -, ,, 1, one, online, new, land, also, (, may, us, free, first, like, get, world, &, de, order, information, 2, without, instagram, 15, use, make, two, :, 10, j, top, time, love, number, many, full, km, –, good, see, france, sale, standard, know, find, right, crianças, sports, take, even, please, site, old, per, made, /, und, forum, black, account, well, last, c, contact, view, la, place, smooth, french, energy, 3, go, best, since, adulto(s), way, must, news, people, 4, united, audience, show, email, data, name, ., ..., read, post, used, thank, report, water, check, article, date, work
# Topic 12: online, ., -, pharmacy, cialis, viagra, quick, buy, overview, ,, de, prescription, en, , pharmacy., indicated, farmacia, treatment, order, farmacie, online., drugs, erectile, y, &, 1, apotheke, re:, new, !, la, us, /, use, without, canadian, generic, best, years,, also, one, free, cheap, >, dysfunction, |, price, first, may, information, levitra, service, faster, 2, super, last, men., ed, works, irish, health, day, dosage, month, discount, medication, mg, tablets,    , products, find, inoculation, like, offers, viagra., pm, see, purchase, make, time, canada, get, help, view, please, e, uk, france, cheap,, dysfunction., years, pharmacy,, sale, prices, loop., good, french, brand, take, 3
# Topic 13: -, 1, /, fra, m, 2, |, ,, new, garden, use, 3, one, 5, information, no., also, may, licensed, first, 4, hour, comments, 6, time, &, us, services, financial, ..., 10, find, make, like, please, see, search, service, f, view, –, 7, number, work, good, :, name, two, islands, free, take, last, back, day, ", de, health, contact, 8, vosges, site, >, know, need, france, made, (, well, return, must, many, want, web, *, year, days, without, 11, room, land, energy, data, week, united, years, people, used, republic, access, add, 12, public, since, privacy, available, 15, per, account, part, even
# Topic 14: _, -, ,, one, may, 1, new, club, also, us, use, 2, first, information, 5, 2022, de, 10, committee, like, /, athletics, love, 3, two, time, 4, without, x, number, see, years, must, take, please, |, free, :, &, people, know, make, –, made, find, even, data, work, well, water, athletic, account, december, france, good, site, life, go, 6, help, ", search, order, last, get, part, du, services, service, (, many, november, [...], world, used, give, said, 12, back, ..., much, access, read, need, since, book, united, right, little, september, contact, day, place, end, great, iphone, airways, policy, social, 7
# Topic 15: -, jewelry, ||, watches, ,, &, j, de, new, 1, ps:, january, /, |, 77, 2, x, one, family, information, :, gift, €, also, may, _, street, first, 0, time, 3, cm, 4, us, rue, pancreatic, number, et, –, 2.2, la, site, search, 2.0, please, +, two, free, 1.8, 5, children, herbeauvilliers, use, add, service, good, 45, *, december, contact, made, (, 6, see, september, like, watch, france, 10, boulet, october, order, accessories, 90, >, make, false, digital, special, find, crianças, 2022, shipping, ), du, place, love, north, take, people, without, 8, d, height, book, small, 12, luxembourg, 30, june
# Topic 16: m, +, fra, -, info, o, mini, bag, case, short, €, ', new, black, handle, information, 2, blue, ,, first, body, &, 1, ih, online,  , , also, 3, compatible, ., one, leather, _, composition, use, may, sem, order, |, de, name, free, faux, white, hand, us, lamp, see, f, 4, products, 5, v1m, ',, site, extra, stamps, time, no., e, fur, like, tubular, inner, 00, :, please, two, without, adaptable, make, fine, get, view, 10, /, available, french, natural, flat, 6, xl, light, y, john, ':, day, years, 52, right, find, green, number, good, close, micro, (, many, buy
# Topic 17: film, -, best, new, award, comedy, academy, winning, cannes, drama, ,, /, films, |, festival, read, nominated, 1, may, 0, kids, order, delivery, •, xx, 2, summer, international, american, stock, notice, adventure, islands, &, also, one, horror, war, 100, british, use, more..., sonicare, de, musical, photo, 3, france, republic, language, western, first, time, information, french, family, awards, view, ©, foreign, feature, limited, movie, united, see, entertainment, download, must, cinema, email, give, social, thriller, crime, 5, us, january, :, free, years, house, picture, children, like, action, rue, romantic, please, get, animated, two, 4, movies, without, street, fantasy, search, wave, news, top
# Topic 18: -, [card], km, centre, average, ,, city, :, star, view, price/night, 1, &, €, 2, new, de, comments), >, hotel, apartment, free, first, trainer, –, 2013, [, 4, 5, information, air, comments, /, article, may, 3, energy, =, hotels, one, 2011, 2014, waste, case, also, 2012, price, 2016, 6, voiron, use, 2017, 0:0, us, airlines, promo, (black, search, victory, number, please, 2010, time, 2015, (, 0, la, world, (ex, dollar, contact, best, l'estartit, street, 10, |, france, service, see, rue, book, days, .., last, 2008, services, date, card, take, car, 2009, good, nautilus, peugeot, ], 7, cancellation, site, 2004, french
# Topic 19:  , online, ., _, -, ,, de, viagra, pharmacy, new, &, philippe, licence, one, buy, also, first, la, may, islands, free, /, us, like, see, forum, –, use, 1, order, get, time, driving, number, treatment, discussion, file, information, change, make, cialis, without, ________, french, |, 2, en, pache., two, maker, take, indicated, health, y, find, many, ', driver's, contact, instagram, know, account, good, erectile, 3, right, replacement, round, republic, best, news, work, per, even, pharmacy., , please, size:, general, site, farmacie, price, made, generic, air, download, back, day, :, paris,, people, since, _______, farmacia, , united, france, last, used, ·
#              docid  highest_topic   topic_0   topic_1   topic_2   topic_3  \
# 0  doc012310000001             15  0.012663  0.014262  0.008591  0.016829
# 1  doc012310000002             10  0.005596  0.005094  0.006606  0.005671
# 2  doc012310000003              5  0.003912  0.004064  0.004314  0.003942
# 3  doc012310000004             11  0.014080  0.068443  0.031435  0.057604
# 4  doc012310000005             18  0.002074  0.002415  0.002068  0.002090
# 5  doc012310000006             14  0.003796  0.004075  0.005067  0.054648
# 6  doc012310000007              9  0.005999  0.014929  0.020400  0.018412
# 7  doc012310000008              1  0.008953  0.377323  0.009844  0.075870
# 8  doc012310000009              3  0.047118  0.024044  0.024336  0.472316
# 9  doc012310000010             15  0.004047  0.004025  0.007984  0.046724
#
#     topic_4   topic_5   topic_6   topic_7  ...  topic_10  topic_11  topic_12  \
# 0  0.012025  0.375100  0.006941  0.008288  ...  0.013387  0.007428  0.005712
# 1  0.004861  0.005077  0.005239  0.004868  ...  0.888313  0.005278  0.005657
# 2  0.004038  0.916477  0.004340  0.004262  ...  0.003961  0.004072  0.004354
# 3  0.030868  0.028030  0.014775  0.012804  ...  0.014521  0.529106  0.010386
# 4  0.002023  0.002093  0.002292  0.002080  ...  0.002156  0.002080  0.002136
# 5  0.003697  0.006552  0.007195  0.003901  ...  0.005076  0.004765  0.006789
# 6  0.007279  0.032493  0.009417  0.007134  ...  0.010605  0.007327  0.010610
# 7  0.017758  0.030975  0.007933  0.015160  ...  0.009572  0.334415  0.008685
# 8  0.022321  0.019257  0.018172  0.015006  ...  0.018349  0.021428  0.015548
# 9  0.004181  0.006874  0.006921  0.003830  ...  0.004228  0.004753  0.004408
#
#    topic_13  topic_14  topic_15  topic_16  topic_17  topic_18  topic_19
# 0  0.016934  0.009465  0.402358  0.009967  0.015374  0.009536  0.019632
# 1  0.005279  0.005381  0.005414  0.005470  0.005321  0.005089  0.014208
# 2  0.003945  0.003993  0.009706  0.003950  0.004260  0.004047  0.004241
# 3  0.013900  0.027416  0.016058  0.012190  0.042816  0.010283  0.013985
# 4  0.002028  0.002066  0.004503  0.002068  0.002237  0.957024  0.002242
# 5  0.004353  0.844817  0.008707  0.003682  0.007137  0.007341  0.004682
# 6  0.027660  0.012904  0.007852  0.005805  0.016788  0.005845  0.072805
# 7  0.007654  0.010786  0.008667  0.008074  0.006807  0.007135  0.025178
# 8  0.078181  0.053482  0.013570  0.013983  0.019338  0.018132  0.028806
# 9  0.004691  0.004251  0.866370  0.004106  0.004651  0.004350  0.004553
#
# [10 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Step 8: Get Topic Distribution for Each Document
topic_distribution = lda_model.transform(vectorized_docs)

# Step 9: Count Documents per Topic
# Extract the topic distribution into a DataFrame
# First, we need to create a new DataFrame with the topic distribution as a list
topic_distribution_list = topic_distribution.select("topicDistribution").collect()

# Create a DataFrame with topic counts
topic_counts = []

# Iterate over each row of topic distributions and sum the occurrences of each topic
for row in topic_distribution_list:
    topic_counts.append(row.topicDistribution)

# Convert list of topic distributions into a DataFrame
topic_counts_df = pd.DataFrame(topic_counts, columns=[f'Topic {i}' for i in range(k)])

# Sum the occurrences of each topic
topic_sums = topic_counts_df.sum().sort_values(ascending=False)

# Step 10: Plot the T16Gopic Distribution
plt.figure(figsize=(10, 6))
topic_sums.plot(kind='bar', color='skyblue')
plt.title('Topic Distribution')
plt.xlabel('Topics')
plt.ylabel('Number of Documents')
plt.xticks(rotation=45)
plt.show()

# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import Tokenizer, StopWordsRemover, CountVectorizer
from pyspark.ml.clustering import LDA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# # Assuming Spark session is already created
# spark = SparkSession.builder.appName("LDA Example").getOrCreate()
# spark.sparkContext.setLogLevel("ERROR")

# # Step 1: Tokenization
# tokenizer = Tokenizer(inputCol="contents", outputCol="words")
# tokenized = tokenizer.transform(docs)

# # Step 2: Remove Stopwords
# remover = StopWordsRemover(inputCol="words", outputCol="filtered_words")
# filtered = remover.transform(tokenized)

# # Step 3: Convert Words to Features using CountVectorizer
# vectorizer = CountVectorizer(inputCol="filtered_words", outputCol="features")
# vector_model = vectorizer.fit(filtered)
# vectorized_docs = vector_model.transform(filtered)

# # Step 4: Train LDA Model
# k = 20  # Number of topics to extract
# lda = LDA(k=k, maxIter=10, featuresCol="features", optimizer="em")
# lda_model = lda.fit(vectorized_docs)

# Step 5: Transform documents into topic distributions
doc_topics = lda_model.transform(vectorized_docs)  # Output: Soft assignment of docs to topics

# Step 6: Extract topic distributions as numpy array
# doc_topic_array = np.array(doc_topics.select("topicDistribution").rdd.map(lambda x: x[0]).collect())
doc_topic_df = doc_topics.select("topicDistribution").toPandas()
doc_topic_array = np.vstack(doc_topic_df["topicDistribution"].apply(lambda v: v.toArray()))

# Step 7: Reduce dimensionality using PCA (or t-SNE for better visualization)
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
doc_topic_2d = tsne.fit_transform(doc_topic_array)

# Step 8: Assign each document to its dominant topic
dominant_topics = np.argmax(doc_topic_array, axis=1)

# Step 9: Convert to Pandas DataFrame for plotting
df_plot = pd.DataFrame({
    "x": doc_topic_2d[:, 0],
    "y": doc_topic_2d[:, 1],
    "topic": dominant_topics
})

# Step 10: Plot scatterplot
plt.figure(figsize=(10, 6))

# Use tab20 since we have 20 topics
scatter = plt.scatter(df_plot["x"], df_plot["y"], c=df_plot["topic"], cmap="tab20", alpha=0.6)

# Create a colorbar and ensure proper topic labels
cbar = plt.colorbar(scatter, label="Topic")
cbar.set_ticks(range(k))  # Ensure colorbar has topic labels from 0 to k-1
cbar.set_ticklabels(range(k))  # Label each tick correctly

plt.xlabel("PCA Dimension 1")
plt.ylabel("PCA Dimension 2")
plt.title("LDA Document Clusters via t-SNE")
plt.show()

# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import Tokenizer, StopWordsRemover, CountVectorizer
from pyspark.ml.clustering import LDA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# # Assuming Spark session is already created
# spark = SparkSession.builder.appName("LDA Example").getOrCreate()
# spark.sparkContext.setLogLevel("ERROR")

# # Step 1: Tokenization
# tokenizer = Tokenizer(inputCol="contents", outputCol="words")
# tokenized = tokenizer.transform(docs)

# # Step 2: Remove Stopwords
# remover = StopWordsRemover(inputCol="words", outputCol="filtered_words")
# filtered = remover.transform(tokenized)

# # Step 3: Convert Words to Features using CountVectorizer
# vectorizer = CountVectorizer(inputCol="filtered_words", outputCol="features")
# vector_model = vectorizer.fit(filtered)
# vectorized_docs = vector_model.transform(filtered)

# # Step 4: Train LDA Model
# k = 20  # Number of topics to extract
# lda = LDA(k=k, maxIter=10, featuresCol="features", optimizer="em")
# lda_model = lda.fit(vectorized_docs)

# Step 5: Transform documents into topic distributions
doc_topics = lda_model.transform(vectorized_docs)  # Output: Soft assignment of docs to topics

# Step 6: Extract topic distributions as numpy array
# doc_topic_array = np.array(doc_topics.select("topicDistribution").rdd.map(lambda x: x[0]).collect())
doc_topic_df = doc_topics.select("topicDistribution").toPandas()
doc_topic_array = np.vstack(doc_topic_df["topicDistribution"].apply(lambda v: v.toArray()))

# Step 7: Reduce dimensionality using PCA (or t-SNE for better visualization)
pca = PCA(n_components=2)  # Reduce to 2D
doc_topic_2d = pca.fit_transform(doc_topic_array)

# Step 8: Assign each document to its dominant topic
dominant_topics = np.argmax(doc_topic_array, axis=1)

# Step 9: Convert to Pandas DataFrame for plotting
df_plot = pd.DataFrame({
    "x": doc_topic_2d[:, 0],
    "y": doc_topic_2d[:, 1],
    "topic": dominant_topics
})

# Step 10: Plot scatterplot
plt.figure(figsize=(10, 6))

# Use tab20 since we have 20 topics
scatter = plt.scatter(df_plot["x"], df_plot["y"], c=df_plot["topic"], cmap="tab20", alpha=0.6)

# Create a colorbar and ensure proper topic labels
cbar = plt.colorbar(scatter, label="Topic")
cbar.set_ticks(range(k))  # Ensure colorbar has topic labels from 0 to k-1
cbar.set_ticklabels(range(k))  # Label each tick correctly

plt.xlabel("PCA Dimension 1")
plt.ylabel("PCA Dimension 2")
plt.title("LDA Document Clusters via PCA")
plt.show()

# %%
import pandas as pd
from IPython.display import display, HTML

topics = {
    0: {"name": "Club & Event Organization/Athletics", "description": "Focus on committees, athletic events, and related organization"},
    1: {"name": "General Information & Service Inquiries", "description": "Broad terms related to information requests, services, and general help"},
    2: {"name": "Film Festivals & Entertainment", "description": "Emphasis on film awards, festivals, and related entertainment topics"},
    3: {"name": "Online Purchases & Medical/Technical Items", "description": "Focus on online orders, pharmaceuticals, and technical equipment"},
    4: {"name": "Personalities & Historical Data", "description": "Mix of names, dates, and file-related terms, suggesting archival or personal data"},
    5: {"name": "Product Reviews & Hotel/Event Planning", "description": "A blend of product feedback, event planning, and hotel-related terms"},
    6: {"name": "Product Specifications & Online Retail", "description": "Focus on product details, features, and online shopping terms"},
    7: {"name": "Vehicle Specifications & Online Forums", "description": "Emphasis on car models, specifications, and online discussion forums"},
    8: {"name": "Online Forums & Communication", "description": "Focus on forum interactions, messages, and general communication"},
    9: {"name": "General Information & Product Listings", "description": "Broad terms related to information, products, and general listings"},
    10: {"name": "Electrical Services & Installations", "description": "Focus on electrical work, installations, and related services"},
    11: {"name": "General Information & Hotel/Travel Inquiries", "description": "Broad terms related to information, hotel bookings, and travel details"},
    12: {"name": "Online Pharmacies & Medical Treatments", "description": "Focus on online pharmaceutical sales and medical treatments"},
    13: {"name": "Online Orders & Product Availability", "description": "Emphasis on online ordering, delivery, and product stock"},
    14: {"name": "Social Media Analytics & Hotel Bookings", "description": "A blend of social media metrics and hotel reservation terms"},
    15: {"name": "Sports Events & Film Production", "description": "Focus on sports competitions and film production roles"},
    16: {"name": "Online Retail & Local/Regional Information", "description": "Mix of product sales, regional information, and public services"},
    17: {"name": "Travel Bookings & Local Information", "description": "Emphasis on travel reservations and local area details"},
    18: {"name": "Vehicle Specifications & Online Sales", "description": "Focus on vehicle details, sales, and related technical terms"},
    19: {"name": "Film Awards & Online Retail/Services", "description": "A blend of film awards and online shopping/service terms"}
}

data = []
for topic_num, topic_info in topics.items():
    data.append({"Topic Number": topic_num, "Topic Name": topic_info["name"], "Topic Description": topic_info["description"]})

df = pd.DataFrame(data)

# Display as HTML table for better presentation in Jupyter Notebook
display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Topic Number</th>
#       <th>Topic Name</th>
#       <th>Topic Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>Club &amp; Event Organization/Athletics</td>
#       <td>Focus on committees, athletic events, and related organization</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>General Information &amp; Service Inquiries</td>
#       <td>Broad terms related to information requests, services, and general help</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Film Festivals &amp; Entertainment</td>
#       <td>Emphasis on film awards, festivals, and related entertainment topics</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>Online Purchases &amp; Medical/Technical Items</td>
#       <td>Focus on online orders, pharmaceuticals, and technical equipment</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>Personalities &amp; Historical Data</td>
#       <td>Mix of names, dates, and file-related terms, suggesting archival or personal data</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>Product Reviews &amp; Hotel/Event Planning</td>
#       <td>A blend of product feedback, event planning, and hotel-related terms</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>Product Specifications &amp; Online Retail</td>
#       <td>Focus on product details, features, and online shopping terms</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>Vehicle Specifications &amp; Online Forums</td>
#       <td>Emphasis on car models, specifications, and online discussion forums</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>Online Forums &amp; Communication</td>
#       <td>Focus on forum interactions, messages, and general communication</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>General Information &amp; Product Listings</td>
#       <td>Broad terms related to information, products, and general listings</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>Electrical Services &amp; Installations</td>
#       <td>Focus on electrical work, installations, and related services</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>General Information &amp; Hotel/Travel Inquiries</td>
#       <td>Broad terms related to information, hotel bookings, and travel details</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>Online Pharmacies &amp; Medical Treatments</td>
#       <td>Focus on online pharmaceutical sales and medical treatments</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>Online Orders &amp; Product Availability</td>
#       <td>Emphasis on online ordering, delivery, and product stock</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>Social Media Analytics &amp; Hotel Bookings</td>
#       <td>A blend of social media metrics and hotel reservation terms</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>Sports Events &amp; Film Production</td>
#       <td>Focus on sports competitions and film production roles</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>Online Retail &amp; Local/Regional Information</td>
#       <td>Mix of product sales, regional information, and public services</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>Travel Bookings &amp; Local Information</td>
#       <td>Emphasis on travel reservations and local area details</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>Vehicle Specifications &amp; Online Sales</td>
#       <td>Focus on vehicle details, sales, and related technical terms</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>Film Awards &amp; Online Retail/Services</td>
#       <td>A blend of film awards and online shopping/service terms</td>
#     </tr>
#   </tbody>
# </table>
